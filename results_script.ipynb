# %% [markdown]
# To jest wynik

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.getcwd()
import numpy as np

# %%
data = pd.read_csv('simulations_results.csv')  #get direction of simulation files!
data.head(20000/50+2)
results = list(data.columns)[2:]
data_env=pd.read_csv('simulations_env_shift_results.csv')
results
# Out:
# ['DG_CLA_mean',
#  'DG_CLA_var',
#  'CSA_mean',
#  'CSA_var',
#  'CLA_mean',
#  'CLA_var',
#  'DSA_mean',
#  'DSA_var']

# %%
colors=['b','r','g','y','k','darkgreen', 'darkblue','orange', 'pink', 'brown', 'magenta', 'darkviolet']

# %%
# TOPOLOGIES SHIFT
plt.figure(1, figsize=(15,10))
plt.ylim(0, 1)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in xrange(8):
    plt.plot(data[results[4]][i*400+i:(i+1)*400+i], colors[i], label=data['Unnamed: 0'][i*400+i])
    plt.plot(data[results[2]][i*400+i:(i+1)*400+i-200], colors[i])
    plt.legend(loc='upper left', frameon=False)
i = 11
plt.plot(data[results[4]][i*400+i:(i+1)*400+i], colors[i], label=data['Unnamed: 0'][i*400+i])
plt.plot(data[results[2]][i*400+i:(i+1)*400+i-200], colors[i])
plt.legend(loc='upper left', frameon=False)

# %%
# TOPOLOGIES SHIFT CLA STANDARD DEVIATION
plt.figure(1, figsize=(15,10))
plt.ylim(0, 0.14)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in xrange(8):
    plt.plot(np.sqrt(data[results[5]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
    #plt.plot(np.sqrt(data[results[3]][i*400+i:(i+1)*400+i-200]), colors[i])
    plt.legend(loc='upper left', frameon=False)
i = 11
plt.plot(np.sqrt(data[results[5]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
#plt.plot(np.sqrt(data[results[3]][i*400+i:(i+1)*400+i-200]), colors[i])
plt.legend(loc='upper left', frameon=False)

# %%
# TOPOLOGIES SHIFT CSA STANDARD DEVIATION
plt.figure(5, figsize=(15,10))
plt.ylim(0, 0.14)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in xrange(8):
    #plt.plot(np.sqrt(data[results[5]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
    plt.plot(np.sqrt(data[results[3]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
    plt.legend(loc='upper left', frameon=False)
i = 11
#plt.plot(np.sqrt(data[results[5]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
plt.plot(np.sqrt(data[results[3]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
plt.legend(loc='upper left', frameon=False)

# %%
# TOPOLOGIES SHIFT
plt.figure(2, figsize=(15,10))
plt.ylim(0, 1)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in range(12)[8:]:
    plt.plot(data[results[4]][i*400+i:(i+1)*400+i], colors[i], label=data['Unnamed: 0'][i*400+i])
    plt.plot(data[results[2]][i*400+i:(i+1)*400+i-200], colors[i])
    plt.legend(loc='upper left', frameon=False)

# %%
# TOPOLOGIES SHIFT CLA STANDARD DEVIATION
plt.figure(2, figsize=(15,10))
plt.ylim(0, 0.14)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in range(12)[8:]:
    plt.plot(np.sqrt(data[results[5]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
    #plt.plot(np.sqrt(data[results[2]][i*400+i:(i+1)*400+i-200]), colors[i])
    plt.legend(loc='upper left', frameon=False)

# %%
# ENVIRONMENT SHIFT
plt.figure(1, figsize=(15,10))
plt.ylim(0, 1)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in xrange(8):
    plt.plot(data_env[results[4]][i*400+i:(i+1)*400+i], colors[i], label=data['Unnamed: 0'][i*400+i])
    plt.plot(data_env[results[2]][i*400+i:(i+1)*400+i-200], colors[i])
    plt.legend(loc='upper left', frameon=False)
i = 11
plt.plot(data_env[results[4]][i*400+i:(i+1)*400+i], colors[i], label=data['Unnamed: 0'][i*400+i])
plt.plot(data_env[results[2]][i*400+i:(i+1)*400+i-200], colors[i])
plt.legend(loc='upper left', frameon=False)

# %%
# ENVIRONMENT SHIFT CLA STANDARD DEVIATION
plt.figure(1, figsize=(15,10))
plt.ylim(0, 0.14)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in xrange(8):
    plt.plot(np.sqrt(data_env[results[5]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
    #plt.plot(np.sqrt(datenv[results[3]][i*400+i:(i+1)*400+i-200]), colors[i])
    plt.legend(loc='upper left', frameon=False)
i = 11
plt.plot(np.sqrt(data_env[results[5]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
#plt.plot(np.sqrt(data_env[results[3]][i*400+i:(i+1)*400+i-200]), colors[i])
plt.legend(loc='upper left', frameon=False)

# %%
# TOPOLOGIES SHIFT
plt.figure(2, figsize=(15,10))
plt.ylim(0, 1)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in range(12)[8:]:
    plt.plot(data_env[results[4]][i*400+i:(i+1)*400+i], colors[i], label=data['Unnamed: 0'][i*400+i])
    plt.plot(data_env[results[2]][i*400+i:(i+1)*400+i-200], colors[i])
    plt.legend(loc='upper left', frameon=False)

# %%
# TOPOLOGIES SHIFT CLA STANDARD DEVIATION
plt.figure(2, figsize=(15,10))
plt.ylim(0, 0.14)
plt.plot(color="blue", linewidth=2.5, linestyle="-", label="cosine")


plt.legend(loc='upper left', frameon=False)
for i in range(12)[8:]:
    plt.plot(np.sqrt(data_env[results[5]][i*400+i:(i+1)*400+i]), colors[i], label=data['Unnamed: 0'][i*400+i])
    #plt.plot(np.sqrt(data_env[results[2]][i*400+i:(i+1)*400+i-200]), colors[i])
    plt.legend(loc='upper left', frameon=False)

# %%
data[800:1210]
# Out:
#          Unnamed: 0  Unnamed: 1  DG_CLA_mean  DG_CLA_var  CSA_mean   CSA_var  \
# 800   max_avg_clust       19950     0.979563    0.000608  0.678750  0.005886
# 801   max_avg_clust       20000     0.979500    0.000632  0.677000  0.005642
# 802     max_max_bet           0     0.000000    0.000000  0.000000  0.000000
# 803     max_max_bet          50     0.033073    0.023754  0.000000  0.000000
# 804     max_max_bet         100     0.152805    0.072497  0.002463  0.000358
# 805     max_max_bet         150     0.270579    0.075908  0.018243  0.001737
# 806     max_max_bet         200     0.376503    0.065095  0.034433  0.002566
# 807     max_max_bet         250     0.457582    0.051490  0.059806  0.003139
# 808     max_max_bet         300     0.517882    0.041485  0.080734  0.003882
# 809     max_max_bet         350     0.567886    0.034225  0.103632  0.004626
# 810     max_max_bet         400     0.612519    0.029055  0.126262  0.005333
# ...
